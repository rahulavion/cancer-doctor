# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('/content/canp.csv')

# %%
df.head()
# Out:
#   Patient Id  Age  Gender  ...  Dry Cough  Snoring   Level
# 0         P1   33       1  ...          3        4     Low
# 1        P10   17       1  ...          7        2  Medium
# 2       P100   35       1  ...          7        2    High
# 3      P1000   37       1  ...          7        5    High
# 4       P101   46       1  ...          2        3    High
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
c=df.corr()
t=c.index

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,20))
g=sns.heatmap(df[t].corr(),annot=True,cmap='RdYlGn')
g

# %%
df.isnull().sum()
# Out:
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
df.drop(['Patient Id'],axis=1,inplace=True)

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# 35    77
# 38    69
# 33    69
# 37    51
# 44    51
# 27    48
# 45    42
# 48    40
# 26    37
# 28    32
# 52    31
# 32    31
# 25    30
# 62    30
# 24    30
# 46    23
# 36    21
# 39    21
# 42    20
# 19    20
# 17    20
# 47    20
# 22    19
# 53    19
# 29    19
# 23    19
# 18    18
# 55    11
# 73    10
# 34    10
# 65    10
# 49    10
# 61    10
# 64    10
# 31     9
# 14     9
# 43     1
# 51     1
# 54     1
# 63     1
# Name: Age, dtype: int64
# 1    598
# 2    402
# Name: Gender, dtype: int64
# 6    326
# 2    201
# 3    173
# 1    141
# 4     90
# 7     30
# 5     20
# 8     19
# Name: Air Pollution, dtype: int64
# 2    202
# 8    188
# 7    167
# 1    152
# 5     90
# 6     80
# 3     80
# 4     41
# Name: Alcohol use, dtype: int64
# 7    405
# 4    133
# 5    111
# 6    110
# 3    101
# 2     70
# 1     60
# 8     10
# Name: Dust Allergy, dtype: int64
# 7    365
# 3    151
# 2    132
# 5    130
# 4    112
# 1     50
# 8     30
# 6     30
# Name: OccuPational Hazards, dtype: int64
# 7    327
# 2    212
# 3    173
# 6    108
# 5    100
# 4     40
# 1     40
# Name: Genetic Risk, dtype: int64
# 6    308
# 2    173
# 4    141
# 3    141
# 7    107
# 5     80
# 1     50
# Name: chronic Lung Disease, dtype: int64
# 7    296
# 2    231
# 3    173
# 6    159
# 4     61
# 5     40
# 1     40
# Name: Balanced Diet, dtype: int64
# 7    356
# 3    193
# 4    191
# 2    140
# 1     70
# 6     30
# 5     20
# Name: Obesity, dtype: int64
# 2    222
# 7    207
# 1    181
# 3    172
# 8     89
# 6     60
# 4     59
# 5     10
# Name: Smoking, dtype: int64
# 2    284
# 7    187
# 4    161
# 3    140
# 8    108
# 1     60
# 6     30
# 5     30
# Name: Passive Smoker, dtype: int64
# 7    296
# 4    191
# 2    181
# 3    153
# 1     80
# 6     40
# 8     30
# 9     19
# 5     10
# Name: Chest Pain, dtype: int64
# 7    187
# 4    172
# 3    171
# 2    121
# 8    119
# 1     71
# 9     60
# 5     50
# 6     49
# Name: Coughing of Blood, dtype: int64
# 3    212
# 2    211
# 4    180
# 1    110
# 8    109
# 5     89
# 6     50
# 9     39
# Name: Fatigue, dtype: int64
# 2    280
# 7    230
# 3    150
# 1    121
# 5    100
# 4     60
# 6     49
# 8     10
# Name: Weight Loss, dtype: int64
# 2    243
# 6    201
# 3    140
# 4     90
# 7     89
# 5     87
# 1     80
# 9     70
# Name: Shortness of Breath, dtype: int64
# 2    240
# 5    171
# 4    163
# 1    149
# 7    139
# 6     68
# 3     60
# 8     10
# Name: Wheezing, dtype: int64
# 1    221
# 4    189
# 2    160
# 8    110
# 5    110
# 6     91
# 3     90
# 7     29
# Name: Swallowing Difficulty, dtype: int64
# 2    240
# 4    220
# 1    131
# 5    120
# 3    100
# 9     80
# 8     59
# 7     40
# 6     10
# Name: Clubbing of Finger Nails, dtype: int64
# 3    230
# 2    192
# 4    180
# 6    170
# 1    139
# 7     69
# 5     20
# Name: Frequent Cold, dtype: int64
# 2    251
# 7    168
# 4    141
# 5    131
# 1    119
# 3    101
# 6     89
# Name: Dry Cough, dtype: int64
# 2    300
# 3    211
# 1    170
# 5    139
# 4    131
# 6     39
# 7     10
# Name: Snoring, dtype: int64
# High      365
# Medium    332
# Low       303
# Name: Level, dtype: int64

# %%
print(df.iloc[:,-1])
# Out:
# 0         Low
# 1      Medium
# 2        High
# 3        High
# 4        High
#         ...
# 995      High
# 996      High
# 997      High
# 998      High
# 999      High
# Name: Level, Length: 1000, dtype: object

# %%
dict={'High':3,'Medium':2,'Low':1}

# %%
dict
# Out:
# {'High': 3, 'Low': 1, 'Medium': 2}

# %%
df['Level']=df['Level'].map(dict)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df[t].corr(),annot=True,cmap='RdYlGn')

# %%
plt.scatter(df['Air Pollution'],df['Level'])

# %%
plt.scatter(df['Alcohol use'],df['Level'])

# %%
plt.scatter(df['Dust Allergy'],df['Level'])

# %%
plt.scatter(df['OccuPational Hazards'],df['Level'])

# %%
plt.scatter(df['Genetic Risk'],df['Level'])

# %%
plt.scatter(df['Balanced Diet'],df['Level'])

# %%
plt.scatter(df['chronic Lung Disease'],df['Level'])

# %%
plt.scatter(df['Obesity'],df['Level'])

# %%
plt.scatter(df['Smoking'],df['Level'])

# %%
plt.scatter(df['Passive Smoker'],df['Level'])

# %%
plt.scatter(df['Chest Pain'],df['Level'])

# %%
plt.scatter(df['Coughing of Blood'],df['Level'])

# %%
plt.scatter(df['Weight Loss'],df['Level'])

# %%
plt.scatter(df['Shortness of Breath'],df['Level'])

# %%
plt.scatter(df['Fatigue'],df['Level'])

# %%
plt.scatter(df['Wheezing'],df['Level'])

# %%
plt.scatter(df['Swallowing Difficulty'],df['Level'])

# %%
plt.scatter(df['Clubbing of Finger Nails'],df['Level'])

# %%
plt.scatter(df['Frequent Cold'],df['Level'])

# %%
plt.scatter(df['Dry Cough'],df['Level'])

# %%
plt.scatter(df['Snoring'],df['Level'])

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Air Pollution', 'Alcohol use', 'Dust Allergy',
#        'OccuPational Hazards', 'Genetic Risk', 'chronic Lung Disease',
#        'Balanced Diet', 'Obesity', 'Smoking', 'Passive Smoker', 'Chest Pain',
#        'Coughing of Blood', 'Fatigue', 'Weight Loss', 'Shortness of Breath',
#        'Wheezing', 'Swallowing Difficulty', 'Clubbing of Finger Nails',
#        'Frequent Cold', 'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
import seaborn as sns

# %%
plt.figure(figsize=(14,6))
sns.barplot(x=df['Level'],y=df['Air Pollution'])

# %%
c=df.corr()
t=c.index

# %%
y=df.iloc[:,-1:]
x=df.iloc[:,:-1]

# %%
y
# Out:
#      Level
# 0        1
# 1        2
# 2        3
# 3        3
# 4        3
# ..     ...
# 995      3
# 996      3
# 997      3
# 998      3
# 999      3
#
# [1000 rows x 1 columns]

# %%
x
# Out:
#      Age  Gender  Air Pollution  ...  Frequent Cold  Dry Cough  Snoring
# 0     33       1              2  ...              2          3        4
# 1     17       1              3  ...              1          7        2
# 2     35       1              4  ...              6          7        2
# 3     37       1              7  ...              6          7        5
# 4     46       1              6  ...              4          2        3
# ..   ...     ...            ...  ...            ...        ...      ...
# 995   44       1              6  ...              4          5        3
# 996   37       2              6  ...              3          1        4
# 997   25       2              4  ...              6          7        2
# 998   18       2              6  ...              4          2        3
# 999   47       1              6  ...              6          7        2
#
# [1000 rows x 23 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,shuffle=True)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model1=RandomForestClassifier()

# %%
model1.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier()

# %%
pre=model1.predict(x_test)

# %%
print(pre)
# Out:
# [3 2 3 1 1 1 3 3 1 3 1 3 2 3 1 2 2 1 2 2 1 2 1 3 2 3 2 2 2 3 3 3 1 3 3 3 3
#  3 2 1 1 1 3 1 1 3 1 2 1 1 2 3 1 1 3 3 2 2 2 3 1 2 2 3 2 1 2 2 2 2 3 3 1 1
#  3 1 3 1 2 3 3 2 2 2 2 2 1 2 1 1 1 3 1 3 1 3 1 3 3 3 2 1 2 3 2 2 1 1 3 3 3
#  3 2 2 3 1 2 1 1 1 1 3 3 2 3 1 3 3 2 3 1 2 2 3 3 1 2 1 2 2 1 2 3 2 1 3 2 2
#  2 3 2 2 3 3 3 3 1 2 3 2 3 2 2 3 1 3 1 1 3 1 1 3 1 2 2 2 3 3 3 3 1 2 2 3 2
#  2 3 1 2 2 1 3 2 3 3 3 1 2 3 2]

# %%
model1.score(x_test,y_test)
# Out:
# 1.0

# %%
import pickle
file=open('canp_model.pkl','wb')
pickle.dump(model1,file)
